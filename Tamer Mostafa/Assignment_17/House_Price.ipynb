# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('/content/Houses prices.csv')
df
# Out:
#                      date         price  bedrooms  ...       city  statezip  country
# 0     2014-05-02 00:00:00  3.130000e+05       3.0  ...  Shoreline  WA 98133      USA
# 1     2014-05-02 00:00:00  2.384000e+06       5.0  ...    Seattle  WA 98119      USA
# 2     2014-05-02 00:00:00  3.420000e+05       3.0  ...       Kent  WA 98042      USA
# 3     2014-05-02 00:00:00  4.200000e+05       3.0  ...   Bellevue  WA 98008      USA
# 4     2014-05-02 00:00:00  5.500000e+05       4.0  ...    Redmond  WA 98052      USA
# ...                   ...           ...       ...  ...        ...       ...      ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0  ...    Seattle  WA 98133      USA
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0  ...   Bellevue  WA 98007      USA
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0  ...     Renton  WA 98059      USA
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0  ...    Seattle  WA 98178      USA
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
df['date']=pd.to_datetime(df['date'],format='%Y-%m-%d %H:%M:%S',errors='coerce')

# %%
df['price'].describe()
# Out:
# count    4.600000e+03
# mean     5.519630e+05
# std      5.638347e+05
# min      0.000000e+00
# 25%      3.228750e+05
# 50%      4.609435e+05
# 75%      6.549625e+05
# max      2.659000e+07
# Name: price, dtype: float64

# %%
df[df['price']==0]
# Out:
#            date  price  bedrooms  ...              city  statezip  country
# 4354 2014-05-05    0.0       3.0  ...       Federal Way  WA 98001      USA
# 4356 2014-05-05    0.0       4.0  ...           Seattle  WA 98199      USA
# 4357 2014-05-05    0.0       6.0  ...            Burien  WA 98146      USA
# 4358 2014-05-06    0.0       5.0  ...          Issaquah  WA 98075      USA
# 4361 2014-05-07    0.0       5.0  ...            Burien  WA 98166      USA
# 4362 2014-05-07    0.0       4.0  ...         Sammamish  WA 98074      USA
# 4374 2014-05-09    0.0       2.0  ...          Enumclaw  WA 98022      USA
# 4376 2014-05-09    0.0       4.0  ...     Normandy Park  WA 98166      USA
# 4382 2014-05-12    0.0       5.0  ...        Snoqualmie  WA 98065      USA
# 4383 2014-05-13    0.0       5.0  ...          Bellevue  WA 98004      USA
# 4385 2014-05-13    0.0       4.0  ...     Mercer Island  WA 98040      USA
# ...

# %%
df=df[df['price']!=0]

# %%
df['price'].describe()
# Out:
# count    4.551000e+03
# mean     5.579059e+05
# std      5.639299e+05
# min      7.800000e+03
# 25%      3.262643e+05
# 50%      4.650000e+05
# 75%      6.575000e+05
# max      2.659000e+07
# Name: price, dtype: float64

# %%
df['view'].value_counts()
# Out:
# 0    4103
# 2     201
# 3     115
# 1      69
# 4      63
# Name: view, dtype: int64

# %%
df['condition'].value_counts()
# Out:
# 3    2851
# 4    1238
# 5     425
# 2      31
# 1       6
# Name: condition, dtype: int64

# %%
df['yr_built'].unique()
# Out:
# array([1955, 1921, 1966, 1963, 1976, 1938, 1989, 1985, 1945, 1948, 1909,
#        1980, 1939, 1965, 1956, 1997, 1987, 1983, 1923, 1954, 2005, 1991,
#        1959, 1920, 1979, 1951, 1967, 2004, 2014, 1995, 1944, 1992, 1957,
#        1978, 1974, 1950, 1990, 1949, 1968, 1977, 1996, 2001, 2000, 1929,
#        2006, 2008, 2009, 2012, 2013, 2007, 1986, 1973, 1988, 1900, 1928,
#        1982, 1960, 2003, 1998, 1942, 1908, 1958, 1971, 1975, 1961, 1924,
#        1902, 1962, 1953, 1999, 1994, 1930, 1984, 2010, 1912, 1947, 1916,
#        1940, 1970, 1952, 1964, 1926, 1905, 1969, 1903, 1943, 1993, 1946,
#        1910, 1904, 1981, 1906, 1922, 2011, 2002, 1917, 1913, 1914, 1937,
#        1925, 1932, 1918, 1972, 1941, 1919, 1936, 1911, 1927, 1931, 1901,
#        1907, 1915, 1935, 1933, 1934])

# %%
sns.jointplot(x=df['view'],y=df['price'])

# %%
df['yr_built'].describe()
# Out:
# count    4551.000000
# mean     1970.795649
# std        29.760073
# min      1900.000000
# 25%      1951.000000
# 50%      1976.000000
# 75%      1997.000000
# max      2014.000000
# Name: yr_built, dtype: float64

# %%
def style(x):
    if x in range(1900,1920):
        return 'first 20s'
    elif x in range(1920,1940):
        return '20s-40s'
    elif x in range(1940,1960):
        return '40s-60s'
    elif x in range(1960,1980):
        return '60s-80s'
    elif x in range(1980,2000):
        return '80s-2000'
    elif x in range(2000,2020):
        return 'last 20s'     
df['yr_built']=df['yr_built'].apply(style)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            date         price  bedrooms  ...       city  statezip  country
# 0    2014-05-02  3.130000e+05       3.0  ...  Shoreline  WA 98133      USA
# 1    2014-05-02  2.384000e+06       5.0  ...    Seattle  WA 98119      USA
# 2    2014-05-02  3.420000e+05       3.0  ...       Kent  WA 98042      USA
# 3    2014-05-02  4.200000e+05       3.0  ...   Bellevue  WA 98008      USA
# 4    2014-05-02  5.500000e+05       4.0  ...    Redmond  WA 98052      USA
# ...         ...           ...       ...  ...        ...       ...      ...
# 4595 2014-07-09  3.081667e+05       3.0  ...    Seattle  WA 98133      USA
# ...

# %%
df['city'].unique()
# Out:
# array(['Shoreline', 'Seattle', 'Kent', 'Bellevue', 'Redmond',
#        'Maple Valley', 'North Bend', 'Lake Forest Park', 'Sammamish',
#        'Auburn', 'Des Moines', 'Bothell', 'Federal Way', 'Kirkland',
#        'Issaquah', 'Woodinville', 'Normandy Park', 'Fall City', 'Renton',
#        'Carnation', 'Snoqualmie', 'Duvall', 'Burien', 'Covington',
#        'Inglewood-Finn Hill', 'Kenmore', 'Newcastle', 'Mercer Island',
#        'Black Diamond', 'Ravensdale', 'Clyde Hill', 'Algona', 'Skykomish',
#        'Tukwila', 'Vashon', 'Yarrow Point', 'SeaTac', 'Medina',
#        'Enumclaw', 'Snoqualmie Pass', 'Pacific', 'Beaux Arts Village',
#        'Preston', 'Milton'], dtype=object)

# %%
df['street'].value_counts()
# Out:
# 2520 Mulberry Walk NE            4
# 2500 Mulberry Walk NE            3
# 12303 Sand Point Way NE          2
# 4507 Linden Ave N                2
# 13800 453rd Ave SE               2
#                                 ..
# 6209 40th Ave NE                 1
# 8930-9034 236th Ave NE           1
# 122 27th Ave E                   1
# 16501-16515 Carlyle Hall Rd N    1
# 171 Lake Washington Blvd         1
# Name: street, Length: 4476, dtype: int64

# %%
df['bathrooms'].describe()#float number for bathrooms??
# Out:
# count    4551.000000
# mean        2.155021
# std         0.776351
# min         0.000000
# 25%         1.750000
# 50%         2.250000
# 75%         2.500000
# max         8.000000
# Name: bathrooms, dtype: float64

# %%
df['floors'].describe()#float number for bedrooms??
# Out:
# count    4551.000000
# mean        1.512195
# std         0.538531
# min         1.000000
# 25%         1.000000
# 50%         1.500000
# 75%         2.000000
# max         3.500000
# Name: floors, dtype: float64

# %%
df['bedrooms']=df['bedrooms'].apply(lambda x:int(x))
df['bathrooms']=df['bathrooms'].apply(lambda x:int(x))
df['floors']=df['floors'].apply(lambda x:int(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
type(df['bedrooms'][5])
# Out:
# numpy.int64

# %%
type(df['bathrooms'][5])
# Out:
# numpy.int64

# %%
df['country'].unique()
# Out:
# array(['USA'], dtype=object)

# %%
df['waterfront'].value_counts()
# Out:
# 0    4521
# 1      30
# Name: waterfront, dtype: int64

# %%
df['price'].describe()
# Out:
# count    4.551000e+03
# mean     5.579059e+05
# std      5.639299e+05
# min      7.800000e+03
# 25%      3.262643e+05
# 50%      4.650000e+05
# 75%      6.575000e+05
# max      2.659000e+07
# Name: price, dtype: float64

# %%
zeroprice=df[df['price']==0]
zeroprice
# Out:
# Empty DataFrame
# Columns: [date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, sqft_above, sqft_basement, yr_built, yr_renovated, street, city, statezip, country]
# Index: []

# %%
df=df[df['price']!=0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4551 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4551 non-null   datetime64[ns]
#  1   price          4551 non-null   float64
#  2   bedrooms       4551 non-null   int64
#  3   bathrooms      4551 non-null   int64
#  4   sqft_living    4551 non-null   int64
#  5   sqft_lot       4551 non-null   int64
#  6   floors         4551 non-null   int64
#  7   waterfront     4551 non-null   int64
#  8   view           4551 non-null   int64
#  9   condition      4551 non-null   int64
#  10  sqft_above     4551 non-null   int64
#  11  sqft_basement  4551 non-null   int64
#  12  yr_built       4551 non-null   object
#  13  yr_renovated   4551 non-null   int64
#  14  street         4551 non-null   object
#  15  city           4551 non-null   object
#  16  statezip       4551 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
sns.heatmap(df.corr(),annot=True)

# %%
df=pd.get_dummies(df,columns=['city','yr_built'],drop_first=True)
df
# Out:
#            date         price  ...  yr_built_first 20s  yr_built_last 20s
# 0    2014-05-02  3.130000e+05  ...                   0                  0
# 1    2014-05-02  2.384000e+06  ...                   0                  0
# 2    2014-05-02  3.420000e+05  ...                   0                  0
# 3    2014-05-02  4.200000e+05  ...                   0                  0
# 4    2014-05-02  5.500000e+05  ...                   0                  0
# ...         ...           ...  ...                 ...                ...
# 4595 2014-07-09  3.081667e+05  ...                   0                  0
# 4596 2014-07-09  5.343333e+05  ...                   0                  0
# 4597 2014-07-09  4.169042e+05  ...                   0                  1
# 4598 2014-07-10  2.034000e+05  ...                   0                  0
# 4599 2014-07-10  2.206000e+05  ...                   0                  0
#
# [4551 rows x 64 columns]

# %%
x=df.drop(['price','date','street','statezip','country','yr_renovated','sqft_lot','sqft_basement','sqft_above'],axis=1)
x
# Out:
#       bedrooms  bathrooms  ...  yr_built_first 20s  yr_built_last 20s
# 0            3          1  ...                   0                  0
# 1            5          2  ...                   0                  0
# 2            3          2  ...                   0                  0
# 3            3          2  ...                   0                  0
# 4            4          2  ...                   0                  0
# ...        ...        ...  ...                 ...                ...
# 4595         3          1  ...                   0                  0
# 4596         3          2  ...                   0                  0
# 4597         3          2  ...                   0                  1
# 4598         4          2  ...                   0                  0
# 4599         3          2  ...                   0                  0
#
# [4551 rows x 55 columns]

# %%
y=df['price']
y
# Out:
# 0       3.130000e+05
# 1       2.384000e+06
# 2       3.420000e+05
# 3       4.200000e+05
# 4       5.500000e+05
#             ...
# 4595    3.081667e+05
# 4596    5.343333e+05
# 4597    4.169042e+05
# 4598    2.034000e+05
# 4599    2.206000e+05
# Name: price, Length: 4551, dtype: float64

# %%
from datasist.structdata import detect_outliers
indx=detect_outliers(df,0,['price'])
df.drop(indx,inplace=True)
sns.boxplot(x='price',data=df)

# %%
# !pip install datasist

# %%
from datasist.structdata import detect_outliers
indx=detect_outliers(df,0,['sqft_living'])
df.drop(indx,inplace=True)
sns.boxplot(x='sqft_living',data=df)

# %%
from datasist.structdata import detect_outliers
indx=detect_outliers(df,0,['sqft_living'])
df.drop(indx,inplace=True)
sns.boxplot(x='sqft_living',data=df)

# %%
sns.boxplot(x='bedrooms',data=x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)
x_train
# Out:
# array([[-1.54213839, -1.04712499, -1.21386295, ..., -0.52978809,
#         -0.27502399, -0.53250845],
#        [-1.54213839, -1.04712499, -1.28535922, ..., -0.52978809,
#         -0.27502399, -0.53250845],
#        [-0.43686365,  0.27602851, -0.97894666, ..., -0.52978809,
#         -0.27502399,  1.87790447],
#        ...,
#        [ 2.87896058,  1.599182  ,  0.04242852, ...,  1.88754715,
#         -0.27502399, -0.53250845],
#        [ 0.6684111 ,  0.27602851, -0.53975534, ..., -0.52978809,
#         -0.27502399, -0.53250845],
#        [ 1.77368584,  0.27602851,  0.20584855, ..., -0.52978809,
#         -0.27502399, -0.53250845]])

# %%
x_test
# Out:
# array([[ 0.6684111 ,  1.599182  ,  0.87995617, ..., -0.52978809,
#          3.63604639, -0.53250845],
#        [ 1.77368584,  0.27602851,  0.91059742, ..., -0.52978809,
#         -0.27502399,  1.87790447],
#        [-1.54213839, -1.04712499, -1.08108418, ..., -0.52978809,
#         -0.27502399, -0.53250845],
#        ...,
#        [ 0.6684111 ,  0.27602851,  0.31819982, ...,  1.88754715,
#         -0.27502399, -0.53250845],
#        [ 1.77368584,  0.27602851,  0.41012358, ..., -0.52978809,
#         -0.27502399, -0.53250845],
#        [-1.54213839, -1.04712499, -1.22407671, ..., -0.52978809,
#          3.63604639, -0.53250845]])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

# %%
models={
    'LR':LinearRegression(),
    'KNN':KNeighborsRegressor(n_neighbors=5),
    'SVR':SVR(),
    'DT':DecisionTreeRegressor(),
    'RF':RandomForestRegressor(n_estimators=15),
    'XGBR':XGBRegressor()
}

# %%
for name,model in models.items():
    print(f'using:{name}')
    model.fit(x_train,y_train)
    print(f'training accuracy: {model.score(x_train,y_train)}')
    print(f'testing accuracy: {model.score(x_test,y_test)}')
    print('_'*30)
# Out:
# using:LR
# training accuracy: 0.25149351388190566
# testing accuracy: -5.660658063320013e+20
# ______________________________
# using:KNN
# training accuracy: 0.3953460400388077
# testing accuracy: 0.37775595104159965
# ______________________________
# using:SVR
# training accuracy: -0.025144948085262575
# testing accuracy: -0.04811664851759523
# ______________________________
# using:DT
# training accuracy: 0.9988192084982479
# testing accuracy: 0.2896708591248429
# ______________________________
# using:RF
# training accuracy: 0.8242599247419956
# testing accuracy: 0.2876807755566656
# ______________________________
# using:XGBR
# [19:18:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# training accuracy: 0.4828448059214936
# testing accuracy: 0.622989108835204
# ______________________________

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4551 entries, 0 to 4599
# Data columns (total 55 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   bedrooms                  4551 non-null   int64
#  1   bathrooms                 4551 non-null   int64
#  2   sqft_living               4551 non-null   int64
#  3   floors                    4551 non-null   int64
#  4   waterfront                4551 non-null   int64
#  5   view                      4551 non-null   int64
#  6   condition                 4551 non-null   int64
#  7   city_Auburn               4551 non-null   uint8
#  8   city_Beaux Arts Village   4551 non-null   uint8
#  9   city_Bellevue             4551 non-null   uint8
#  10  city_Black Diamond        4551 non-null   uint8
#  11  city_Bothell              4551 non-null   uint8
#  12  city_Burien               4551 non-null   uint8
#  13  city_Carnation            4551 non-null   uint8
# ...
