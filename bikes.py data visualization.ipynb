# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('data/bikes.csv')
df
# Out:
#                   datetime  season  holiday  workingday weather   temp  \
# 0      2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1      2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2      2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3      2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4      2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                    ...     ...      ...         ...     ...    ...
# 10881  2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882  2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883  2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884  2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885  2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count
# ...

# %%
df.describe()
# Out:
#             holiday   workingday         temp     humidity    windspeed  \
# count  10030.000000  9388.000000  8104.000000  7462.000000  6820.000000
# mean       0.029113     0.678206    20.317665    61.790673    12.708806
# std        0.168131     0.467189     7.818568    19.262084     8.131154
# min        0.000000     0.000000     0.820000     0.000000     0.000000
# 25%        0.000000     0.000000    13.940000    47.000000     7.001500
# 50%        0.000000     1.000000    20.500000    62.000000    12.998000
# 75%        0.000000     1.000000    26.240000    77.000000    16.997900
# max        1.000000     1.000000    41.000000   100.000000    56.996900
#
#              casual    registered  rented_bikes_count
# count  10886.000000  10886.000000        10886.000000
# mean      36.021955    155.552177          191.574132
# std       49.960477    151.039033          181.144454
# min        0.000000      0.000000            1.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   datetime            10886 non-null  object
#  1   season              10672 non-null  object
#  2   holiday             10030 non-null  float64
#  3   workingday          9388 non-null   float64
#  4   weather             8746 non-null   object
#  5   temp                8104 non-null   float64
#  6   humidity            7462 non-null   float64
#  7   windspeed           6820 non-null   float64
#  8   casual              10886 non-null  int64
#  9   registered          10886 non-null  int64
#  10  rented_bikes_count  10886 non-null  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 935.6+ KB

# %%
df.columns
# Out:
# Index(['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'humidity', 'windspeed', 'casual', 'registered', 'rented_bikes_count'],
#       dtype='object')

# %%
df['registered'].value_counts()[5]
# Out:
# 177

# %%
df['casual'].value_counts()[20]
# Out:
# 120

# %%
df['rented_bikes_count'].value_counts()[14]
# Out:
# 66

# %%
df['rented_bikes_count'].value_counts()
# Out:
# 5      169
# 4      149
# 3      144
# 6      135
# 2      132
#       ...
# 667      1
# 603      1
# 587      1
# 970      1
# 843      1
# Name: rented_bikes_count, Length: 822, dtype: int64

# %%
df['season'].value_counts()
# Out:
# Winter    2688
# Fall      2680
# Summer    2670
# Spring    2634
# Name: season, dtype: int64

# %%
df['weather'].value_counts()
# Out:
# Clear    5793
# Mist     2259
# Rainy     693
# Snowy       1
# Name: weather, dtype: int64

# %%
df['registered'].max()
# Out:
# 886

# %%
df['casual'].max()
# Out:
# 367

# %% [markdown]
# so regigestered is more

# %%
df[['registered','rented_bikes_count']].corr()
# Out:
#                     registered  rented_bikes_count
# registered            1.000000            0.970948
# rented_bikes_count    0.970948            1.000000

# %%
df['registered'].mean()
# Out:
# 155.5521771082124

# %% [markdown]
# # data visualization

# %%
tips=sns.load_dataset('bikes')
tips
# Out:
#                   datetime  season  holiday  workingday weather   temp  \
# 0      2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1      2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2      2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3      2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4      2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                    ...     ...      ...         ...     ...    ...
# 10881  2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882  2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883  2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884  2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885  2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count
# ...

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   datetime            10886 non-null  object
#  1   season              10672 non-null  object
#  2   holiday             10030 non-null  float64
#  3   workingday          9388 non-null   float64
#  4   weather             8746 non-null   object
#  5   temp                8104 non-null   float64
#  6   humidity            7462 non-null   float64
#  7   windspeed           6820 non-null   float64
#  8   casual              10886 non-null  int64
#  9   registered          10886 non-null  int64
#  10  rented_bikes_count  10886 non-null  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 935.6+ KB

# %%
tips[(tips['season']=='Spring')&(tips['workingday']=='1.0')].mean().casual
# Out:
# nan

# %%
sns.distplot(tips['rented_bikes_count'])
# Out:
# C:\Users\ahmed\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='rented_bikes_count', ylabel='Density'>

# %%
sns.distplot(tips['registered'],color='m',bins=30)
# Out:
# C:\Users\ahmed\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='registered', ylabel='Density'>

# %%
sns.distplot(tips['rented_bikes_count'],color='m',bins=30)
# Out:
# C:\Users\ahmed\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='rented_bikes_count', ylabel='Density'>

# %%
sns.kdeplot(tips['rented_bikes_count'],color='m',shade=True)
# Out:
# <AxesSubplot:xlabel='rented_bikes_count', ylabel='Density'>

# %%
sns.kdeplot(tips['registered'],color='m',shade=True)
# Out:
# <AxesSubplot:xlabel='registered', ylabel='Density'>

# %%
sns.distplot(tips['humidity'])
# Out:
# C:\Users\ahmed\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='humidity', ylabel='Density'>

# %%
sns.kdeplot(tips['humidity'],color='m',shade=True)
# Out:
# <AxesSubplot:xlabel='humidity', ylabel='Density'>

# %%
sns.jointplot(x='humidity',y='registered',data=tips)

# %%
sns.jointplot(x='humidity',y='registered',data=tips,kind='kde')

# %%
sns.jointplot(x='humidity',y='registered',data=tips,kind='hex')

# %%
sns.jointplot(x='humidity',y='registered',data=tips,kind='scatter',hue='season')

# %%
sns.pairplot(tips,height=4,aspect=1.4)

# %%
sns.boxplot(x='humidity',y='registered',data=tips)
# Out:
# <AxesSubplot:xlabel='humidity', ylabel='registered'>

# %%
sns.violinplot(x='humidity',y='registered',data=tips)
# Out:
# <AxesSubplot:xlabel='humidity', ylabel='registered'>

# %%
sns.stripplot(x='humidity',y='registered',data=tips)
# Out:
# <AxesSubplot:xlabel='humidity', ylabel='registered'>

# %%
sns.swarmplot(x='humidity',y='registered',data=tips)
# Out:
# C:\Users\ahmed\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 78.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ahmed\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ahmed\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 20.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ahmed\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 37.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.boxplot(x='humidity',y='casual',data=tips)
# Out:
# <AxesSubplot:xlabel='humidity', ylabel='casual'>

# %%
sns.barplot(x='humidity',y='casual',data=tips)
# Out:
# <AxesSubplot:xlabel='humidity', ylabel='casual'>

# %%
sns.countplot(x='casual',data=tips)
# Out:
# <AxesSubplot:xlabel='casual', ylabel='count'>

# %%
tips.corr()
# Out:
#                      holiday  workingday      temp  humidity  windspeed  \
# holiday             1.000000   -0.249189 -0.001047  0.016190   0.010463
# workingday         -0.249189    1.000000  0.018954 -0.019167   0.020668
# temp               -0.001047    0.018954  1.000000 -0.068240  -0.025425
# humidity            0.016190   -0.019167 -0.068240  1.000000  -0.312628
# windspeed           0.010463    0.020668 -0.025425 -0.312628   1.000000
# casual              0.042519   -0.318348  0.466035 -0.344939   0.085055
# registered         -0.021017    0.118612  0.315430 -0.266432   0.089105
# rented_bikes_count -0.005827    0.010940  0.391867 -0.317282   0.097747
#
#                       casual  registered  rented_bikes_count
# holiday             0.042519   -0.021017           -0.005827
# workingday         -0.318348    0.118612            0.010940
# temp                0.466035    0.315430            0.391867
# humidity           -0.344939   -0.266432           -0.317282
# ...

# %%
sns.heatmap(tips.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(tips.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(tips.corr(),linecolor='white',linewidths=2)
# Out:
# <AxesSubplot:>
