# %%
import sqlite3

#01) Write a sql query to get books that has rate >=3 and has 'Mr' in its name
connection=sqlite3.connect('books.db')
rows=connection.execute("select * from book_price_rate where rate >=3 and booktitle like '%Mr%'").fetchall()
connection.close()
if rows==[]:
    print('Data Doesnt exist')
else:    
    for id1,book,price,rate  in rows :
        print(f'book id: {id1} book name: {book} its price: {price} and rate:{rate} ')
# Out:
# book id: 35 book name: Mrs. Houdini its price: 30.25 and rate:5
# book id: 154 book name: My Mrs. Brown its price: 24.48 and rate:3

# %%
#02) Write a sql query to get books that has rate >=3 or price > 20
connection=sqlite3.connect('books.db')
rows=connection.execute("select * from book_price_rate where rate >=3 and price>20").fetchall()
connection.close()
if rows==[]:
    print('Data Doesnt exist')
else:    
    for id1,book,price,rate  in rows :
        print(f'book id: {id1} book name: {book} its price: {price} and rate:{rate} ')
# Out:
# book id: 1 book name: Full Moon over Noahâs Ark: An Odyssey to Mount Ararat and Beyond its price: 49.43 and rate:4
# book id: 2 book name: See America: A Celebration of Our National Parks & Treasured Sites its price: 48.87 and rate:3
# book id: 4 book name: Under the Tuscan Sun its price: 37.33 and rate:3
# book id: 7 book name: A Year in Provence (Provence #1) its price: 56.88 and rate:4
# book id: 9 book name: Neither Here nor There: Travels in Europe its price: 38.95 and rate:3
# book id: 10 book name: 1,000 Places to See Before You Die its price: 26.08 and rate:5
# book id: 11 book name: Sharp Objects its price: 47.82 and rate:4
# book id: 13 book name: The Past Never Ends its price: 56.5 and rate:4
# book id: 15 book name: The Murder of Roger Ackroyd (Hercule Poirot #4) its price: 44.1 and rate:4
# book id: 19 book name: A Time of Torment (Charlie Parker #14) its price: 48.35 and rate:5
# book id: 21 book name: Poisonous (Max Revere Novels #3) its price: 26.8 and rate:3
# ...

# %%
#03) Write a sql query to get books that has rate not 3

connection=sqlite3.connect('lec10_booktables_shimaaelsayed.db')
rows=connection.execute("select * from booktitle_price_rate where rate !=3 ").fetchall()
connection.close()
if rows==[]:
    print('Data Doesnt exist')
else:    
    for book,price,rate  in rows :
        print(f'book name: {book} its price: {price} and rate:{rate} ')
# Out:
# book name: Tipping the Velvet its price: 53.74 and rate:1
# book name: Soumission its price: 50.1 and rate:1
# book name: Sharp Objects its price: 47.82 and rate:4
# book name: Sapiens: A Brief History of Humankind its price: 54.23 and rate:5
# book name: The Requiem Red its price: 22.65 and rate:1
# book name: The Dirty Little Secrets of Getting Your Dream Job its price: 33.34 and rate:4
# book name: The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics its price: 22.6 and rate:4
# book name: The Black Maria its price: 52.15 and rate:1
# book name: Starving Hearts (Triangular Trade Trilogy, #1) its price: 13.99 and rate:2
# book name: Shakespeare's Sonnets its price: 20.66 and rate:4
# book name: Set Me Free its price: 17.46 and rate:5
# book name: Scott Pilgrim's Precious Little Life (Scott Pilgrim #1) its price: 52.29 and rate:5
# book name: Rip it Up and Start Again its price: 35.02 and rate:5
# book name: Olio its price: 23.88 and rate:1
# ...

# %%
#04) Write a sql query to get books that has price between 10 and 40 and has rate 3 or 4 or 1
connection=sqlite3.connect('books.db')
rows=connection.execute("select * from book_price_rate where rate in (1,3,4) and price between 10 and 20").fetchall()
connection.close()
if rows==[]:
    print('Data Doesnt exist')
else:    
    for id1,book,price,rate  in rows :
        print(f'book id: {id1} book name: {book} its price: {price} and rate:{rate} ')
# Out:
# book id: 12 book name: In a Dark, Dark Wood its price: 19.63 and rate:1
# book id: 14 book name: A Murder in Time its price: 16.64 and rate:1
# book id: 17 book name: That Darkness (Gardiner and Renner #1) its price: 13.92 and rate:1
# book id: 18 book name: Tastes Like Fear (DI Marnie Rome #3) its price: 10.69 and rate:1
# book id: 24 book name: Hide Away (Eve Duncan #20) its price: 11.84 and rate:1
# book id: 27 book name: Playing with Fire its price: 13.71 and rate:3
# book id: 41 book name: The Constant Princess (The Tudor Court #1) its price: 16.62 and rate:3
# book id: 52 book name: Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2) its price: 16.28 and rate:1
# book id: 53 book name: This One Summer its price: 19.49 and rate:4
# book id: 58 book name: Pop Gun War, Volume 1: Gift its price: 18.97 and rate:1
# book id: 59 book name: Patience its price: 10.16 and rate:3
# ...

# %%
#05) Write a sql query to get the top 5 most expensive books 
#(order books desc with price column and then limit the result to the first 5).

connection=sqlite3.connect('books.db')
rows=connection.execute("select * from book_price_rate order by price desc limit 5").fetchall()
connection.close()
if rows==[]:
    print('Data Doesnt exist')
else:    
    for id1,book,price,rate  in rows :
        print(f'book id: {id1} book name: {book} its price: {price} and rate:{rate} ')
# Out:
# book id: 118 book name: The Perfect Play (Play by Play #1) its price: 59.99 and rate:3
# book id: 372 book name: Civilization and Its Discontents its price: 59.95 and rate:2
# book id: 481 book name: The Bone Hunters (Lexy Vaughan & Steven Macaulay #2) its price: 59.71 and rate:3
# book id: 416 book name: Thomas Jefferson and the Tripoli Pirates: The Forgotten War That Changed American History its price: 59.64 and rate:1
# book id: 25 book name: Boar Island (Anna Pigeon #19) its price: 59.48 and rate:3

# %%
#06) Write a sql query to get the 3rd 10 books in the books table order first by rate desc and then by price asc

connection=sqlite3.connect('books.db')
rows=connection.execute("select * from book_price_rate order by rate desc , price asc limit 10 offset 2").fetchall()
connection.close()
if rows==[]:
    print('Data Doesnt exist')
else:    
    for id1,book,price,rate  in rows :
        print(f'book id: {id1} book name: {book} its price: {price} and rate:{rate} ')
# Out:
# book id: 457 book name: The Third Wave: An Entrepreneurâs Vision of the Future its price: 12.61 and rate:5
# book id: 163 book name: Walt Disney's Alice in Wonderland its price: 12.96 and rate:5
# book id: 281 book name: Princess Between Worlds (Wide-Awake Princess #5) its price: 13.34 and rate:5
# book id: 57 book name: Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1) its price: 13.61 and rate:5
# book id: 126 book name: Some Women its price: 13.73 and rate:5
# book id: 323 book name: The Epidemic (The Program 0.6) its price: 14.44 and rate:5
# book id: 115 book name: A Gentleman's Position (Society of Gentlemen #3) its price: 14.75 and rate:5
# book id: 388 book name: Hyperbole and a Half: Unfortunate Situations, Flawed Coping Mechanisms, Mayhem, and Other Things That Happened its price: 14.75 and rate:5
# book id: 384 book name: Fifty Shades Freed (Fifty Shades #3) its price: 15.36 and rate:5
# ...

# %%
#07) Write a sql query to add a new category in categories table and add 5 books to this category
#in books table with title, rate and price

connection=sqlite3.connect('books.db')

cur = connection.cursor()
# Insert data

cur.execute("INSERT INTO book_price_rate VALUES (517,'book1',1,1)")
cur.execute("INSERT INTO book_price_rate VALUES (518,'book2',2,2)")
cur.execute("INSERT INTO book_price_rate VALUES (519,'book3',3,3)")
cur.execute("INSERT INTO book_price_rate VALUES (520,'book4',4,4)")
cur.execute("INSERT INTO book_price_rate VALUES (521,'book5',5,5)")


# Save (commit) the changes
connection.commit()

connection.close()

# %%
#checking if executed
connection=sqlite3.connect('books.db')
rows=connection.execute("select * from book_price_rate").fetchall()
connection.close()
if rows==[]:
    print('Data Doesnt exist')
else:    
    for id1,book,price,rate  in rows :
        print(f'book id: {id1} book name: {book} its price: {price} and rate:{rate} ')
# Out:
# book id: 0 book name: It's Only the Himalayas its price: 45.17 and rate:2
# book id: 1 book name: Full Moon over Noahâs Ark: An Odyssey to Mount Ararat and Beyond its price: 49.43 and rate:4
# book id: 2 book name: See America: A Celebration of Our National Parks & Treasured Sites its price: 48.87 and rate:3
# book id: 3 book name: Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel its price: 36.94 and rate:2
# book id: 4 book name: Under the Tuscan Sun its price: 37.33 and rate:3
# book id: 5 book name: A Summer In Europe its price: 44.34 and rate:2
# book id: 6 book name: The Great Railway Bazaar its price: 30.54 and rate:1
# book id: 7 book name: A Year in Provence (Provence #1) its price: 56.88 and rate:4
# book id: 8 book name: The Road to Little Dribbling: Adventures of an American in Britain (Notes From a Small Island #2) its price: 23.21 and rate:1
# book id: 9 book name: Neither Here nor There: Travels in Europe its price: 38.95 and rate:3
# ...

# %%
#08) Write a sql query to update book's rate to 3 that thier price < 20£


connection=sqlite3.connect('books.db')

cur = connection.cursor()
# Insert data

cur.execute("update book_price_rate set rate=3 where price<20")



# Save (commit) the changes
connection.commit()

connection.close()

# %%
#checking if executed
connection=sqlite3.connect('books.db')
rows=connection.execute("select * from book_price_rate where price<20").fetchall()
connection.close()
if rows==[]:
    print('Data Doesnt exist')
else:    
    for id1,book,price,rate  in rows :
        print(f'book id: {id1} book name: {book} its price: {price} and rate:{rate} ')
# Out:
# book id: 12 book name: In a Dark, Dark Wood its price: 19.63 and rate:3
# book id: 14 book name: A Murder in Time its price: 16.64 and rate:3
# book id: 17 book name: That Darkness (Gardiner and Renner #1) its price: 13.92 and rate:3
# book id: 18 book name: Tastes Like Fear (DI Marnie Rome #3) its price: 10.69 and rate:3
# book id: 20 book name: A Study in Scarlet (Sherlock Holmes #1) its price: 16.73 and rate:3
# book id: 24 book name: Hide Away (Eve Duncan #20) its price: 11.84 and rate:3
# book id: 27 book name: Playing with Fire its price: 13.71 and rate:3
# book id: 40 book name: Lilac Girls its price: 17.28 and rate:3
# book id: 41 book name: The Constant Princess (The Tudor Court #1) its price: 16.62 and rate:3
# book id: 52 book name: Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2) its price: 16.28 and rate:3
# book id: 53 book name: This One Summer its price: 19.49 and rate:3
# ...

# %%
#09) Write a sql query to delete all books that have price > 50£ and has rate <= 2.


connection=sqlite3.connect('books.db')

cur = connection.cursor()
# Insert data

cur.execute("delete from book_price_rate where price>50 and rate <=2 ")



# Save (commit) the changes
connection.commit()

connection.close()

# %%
#checking if executed
connection=sqlite3.connect('books.db')
rows=connection.execute("select * from book_price_rate where price>50 and rate<=2").fetchall()
connection.close()
if rows==[]:
    print('Data Doesnt exist')
else:    
    for id1,book,price,rate  in rows :
        print(f'book id: {id1} book name: {book} its price: {price} and rate:{rate} ')
# Out:
# Data Doesnt exist

# %%
#10) Write a sql query to count the number of books that have 'Secret' in thier names and price
#between 10£ and 25£.

connection=sqlite3.connect('books.db')
rows=connection.execute("select count(BookTitle) from book_price_rate where BookTitle like '%Secret%' and price between 10 and 25").fetchall()
connection.close()
if rows==[]:
    print('Data Doesnt exist')
else:    
    print("the number of books that have 'Secret' in thier names and price between 10£ and 25£ is: ",rows[0][0])
# Out:
# the number of books that have 'Secret' in thier names and price between 10£ and 25£ is:  3

# %%
#11) Write a sql query to get the minimum & maximum price for all the books that have rate 5.

connection=sqlite3.connect('books.db')
rows=connection.execute("select min(price) from book_price_rate  where rate=5 ").fetchall()
connection.close()
if rows==[]:
    print('Data Doesnt exist')
else:    
    print("the minimum price of rate=5 : ",rows[0][0])
connection=sqlite3.connect('books.db')
rows=connection.execute("select max(price) from book_price_rate where rate=5 ").fetchall()
connection.close()
if rows==[]:
    print('Data Doesnt exist')
else:    
    print("the maximum price of rate=5 : ",rows[0][0])
# Out:
# the minimum price of rate=5 :  20.02
# the maximum price of rate=5 :  59.04

# %%
#12) Write a sql query to calculate the avg price for all the books that have rate 5.

connection=sqlite3.connect('books.db')
rows=connection.execute("select avg(price) from book_price_rate where rate=5 ").fetchall()
connection.close()

if rows==[]:
    print('Data Doesnt exist')
else:    
    print("the avg price for all the books that have rate 5 : ",rows[0][0])
# Out:
# the avg price for all the books that have rate 5 :  40.41082352941176

# %%
#13) Write a sql query to sum all book's price that have rate 2 and price between 10 and 40

connection=sqlite3.connect('books.db')
rows=connection.execute("select sum(price) from book_price_rate where rate=2 and price between 10 and 40 ").fetchall()
connection.close()

if rows==[]:
    print('Data Doesnt exist')
else:    
    print("the sum of all book's price that have rate 2 and price between 10 and 40: ",rows[0][0])
# Out:
# the sum of all book's price that have rate 2 and price between 10 and 40:  1333.4900000000002

# %%
# 14) Write a sql query to join both books & categories table into one new table containing
#book_name & category_name & book_rate and book_price
import sqlite3
connection=sqlite3.connect('books.db')
rows=connection.execute("SELECT book_price_rate.BookTitle, book_price_rate.price, book_price_rate.rate, categories_and_books.BookTitle, book_categ.Category FROM book_price_rate FULL OUTER JOIN book_categ ON book_price_rate.BookTitle=book_categ.BookTitle ").fetchall()
connection.close()

if rows==[]:
    print('Data Doesnt exist')
else:    
    print("the sum of all book's price that have rate 2 and price between 10 and 40: ",rows[0][0])
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-19-e825845a68f0> in <module>
#       3 import sqlite3
#       4 connection=sqlite3.connect('books.db')
# ----> 5 rows=connection.execute("SELECT book_price_rate.BookTitle, book_price_rate.price, book_price_rate.rate, categories_and_books.BookTitle, book_categ.Category FROM book_price_rate FULL OUTER JOIN book_categ ON book_price_rate.BookTitle=book_categ.BookTitle ").fetchall()
#       6 connection.close()
#       7
#
# OperationalError: RIGHT and FULL OUTER JOINs are not currently supported

# %%
#15) Write a sql query to calculate how many books each rate has and have price between 20£ and 30£


connection=sqlite3.connect('books.db')
rows=connection.execute("select rate, count(BookTitle) from book_price_rate where price between 20 and 30 group by rate").fetchall()
connection.close()

if rows==[]:
    print('Data Doesnt exist')
else:    
    for rate,count in rows :
        print(f'rate: {rate} its count: {count} ')
# Out:
# rate: 1 its count: 31
# rate: 2 its count: 17
# rate: 3 its count: 23
# rate: 4 its count: 17
# rate: 5 its count: 21

# %%
#16) Write a sql query to calculate how many books each category has having count > 10.

connection=sqlite3.connect('books.db')
rows=connection.execute("select category, count(BookTitle) from book_categ").fetchall()
connection.close()

if rows==[]:
    print('Data Doesnt exist')
else:    
    for  category, count in rows :
        print(f' category: {category} its count: {count} ')
# Out:
#  category: Travel its count: 517

# %%
#17) Write a sql query to get all books with category_name='Music' using subquery.

connection=sqlite3.connect('books.db')
rows=connection.execute("select *from book_categ where Category=(select category from book_categ where category='Music')").fetchall()
connection.close()

if rows==[]:
    print('Data Doesnt exist')
else:    
    for id2,book,categ  in rows :
        print(f'book id: {id2} book name: {book} its category: {categ} ')
# Out:
# book id: 205 book name: Rip it Up and Start Again its category: Music
# book id: 206 book name: Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991 its category: Music
# book id: 207 book name: How Music Works its category: Music
# book id: 208 book name: Love Is a Mix Tape (Music #1) its category: Music
# book id: 209 book name: Please Kill Me: The Uncensored Oral History of Punk its category: Music
# book id: 210 book name: Kill 'Em and Leave: Searching for James Brown and the American Soul its category: Music
# book id: 211 book name: Chronicles, Vol. 1 its category: Music
# book id: 212 book name: This Is Your Brain on Music: The Science of a Human Obsession its category: Music
# book id: 213 book name: Orchestra of Exiles: The Story of Bronislaw Huberman, the Israel Philharmonic, and the One Thousand Jews He Saved from Nazi Horrors its category: Music
# book id: 214 book name: No One Here Gets Out Alive its category: Music
# ...

# %%
# read db using pandas
import pandas as pd
connection = sqlite3.connect('books.db')

df1 = pd.read_sql_query("SELECT * FROM book_price_rate", connection)

df2 = pd.read_sql_query("SELECT * FROM book_categ", connection)


connection.close()

display(df1)
display(df2)
# Out:
#       id                                          BookTitle  Price  Rate
# 0      0                            It's Only the Himalayas  45.17     2
# 1      1  Full Moon over Noahâs Ark: An Odyssey to Mou...  49.43     4
# 2      2  See America: A Celebration of Our National Par...  48.87     3
# 3      3  Vagabonding: An Uncommon Guide to the Art of L...  36.94     2
# 4      4                               Under the Tuscan Sun  37.33     3
# ..   ...                                                ...    ...   ...
# 475  517                                              book1   1.00     3
# 476  518                                              book2   2.00     3
# 477  519                                              book3   3.00     3
# 478  520                                              book4   4.00     3
# 479  521                                              book5   5.00     3
#
# [480 rows x 4 columns]
#       id                                          BookTitle  Category
# ...
