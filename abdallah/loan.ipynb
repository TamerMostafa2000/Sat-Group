# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('loan_data.csv')
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.Gender.unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
df.Married.unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df.Education.unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %%
df.Self_Employed.unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df.Property_Area.unique()
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %%
df.Loan_Status.unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
sns.pairplot(df)

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#males vs females in respect to laon status

df.groupby('Gender')['Loan_Status'].describe()
# Out:
#        count unique top freq
# Gender
# Female   112      2   Y   75
# Male     489      2   Y  339

# %%
sns.countplot(x='Loan_Status', hue='Gender', data=df)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='count'>

# %%
# which is higher who has loan: married or not? in respect to Gender
df.groupby(['Married', 'Gender', 'Loan_Status']).describe()
# Out:
#                            ApplicantIncome                                    \
#                                      count         mean          std     min
# Married Gender Loan_Status
# No      Female N                      29.0  3955.482759  2171.807832   416.0
#                Y                      51.0  4815.568627  3826.073294   645.0
#         Male   N                      49.0  5702.714286  4130.707350  1442.0
#                Y                      81.0  4953.901235  4524.544122  1800.0
# Yes     Female N                       8.0  4583.875000  3132.787369  1378.0
#                Y                      23.0  4915.130435  4512.751482   210.0
#         Male   N                     101.0  5935.178218  8795.646741   150.0
#                Y                     256.0  5369.503906  5749.036911  1025.0
#
#                                                                \
#                                 25%     50%      75%      max
# Married Gender Loan_Status
# ...

# %%
sns.countplot(data=df, x='Married', hue='Loan_Status', dodge=True)
# Out:
# <AxesSubplot:xlabel='Married', ylabel='count'>

# %%
#who has the biggest loan?
df.info()
df.sort_values(by='LoanAmount',ascending=False).head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# ...

# %%
sns.histplot(x='LoanAmount', data=df)
# Out:
# <AxesSubplot:xlabel='LoanAmount', ylabel='Count'>

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.Loan_Amount_Term.unique()
# Out:
# array([360., 120., 240.,  nan, 180.,  60., 300., 480.,  36.,  84.,  12.])

# %%
# correlation etween loan anount term and loan amount
df[['LoanAmount','Loan_Amount_Term']].corr()
# Out:
#                   LoanAmount  Loan_Amount_Term
# LoanAmount          1.000000          0.039447
# Loan_Amount_Term    0.039447          1.000000

# %%
sns.heatmap(data=df[['LoanAmount','Loan_Amount_Term']])
# Out:
# <AxesSubplot:>

# %%
# which has the biggest loan in accordance to graduates?? is he/she married or not? what is their gender??
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.groupby('Education')['LoanAmount'].max()
# Out:
# Education
# Graduate        700.0
# Not Graduate    279.0
# Name: LoanAmount, dtype: float64

# %%
df.groupby(['Education', 'Gender', 'Married'])['LoanAmount'].describe()
# Out:
#                              count        mean         std   min    25%  \
# Education    Gender Married
# Graduate     Female No        65.0  118.061538   59.770885   9.0   84.0
#                     Yes       25.0  160.520000  125.764701  36.0  108.0
#              Male   No        95.0  145.968421   89.479874  47.0   97.0
#                     Yes      266.0  162.281955   90.244988  17.0  110.0
# Not Graduate Female No        13.0  106.384615   47.394688  53.0   70.0
#                     Yes        6.0  123.333333   31.129836  98.0  100.5
#              Male   No        30.0  104.800000   36.136141  25.0   94.5
#                     Yes       77.0  125.441558   39.440993  45.0  100.0
#
#                                50%    75%    max
# Education    Gender Married
# Graduate     Female No       112.0  136.0  350.0
#                     Yes      127.0  144.0  600.0
#              Male   No       126.0  170.0  650.0
#                     Yes      138.5  187.0  600.0
# ...

# %%
sns.catplot(x='Education', y='LoanAmount', hue='Gender', data=df, row='Married', dodge=True, kind = 'bar')

# %%
df.Dependents.unique()
# Out:
# array(['0', '1', '2', '3+', nan], dtype=object)

# %%
df.groupby('Married')['Dependents'].count()
# Out:
# Married
# No     209
# Yes    390
# Name: Dependents, dtype: int64

# %%
df.groupby(['Married','Dependents'])['LoanAmount'].describe()
# Out:
#                     count        mean         std    min     25%    50%  \
# Married Dependents
# No      0           166.0  126.240964   76.086568    9.0   83.25  115.0
#         1            22.0  118.500000   39.541118   40.0   94.25  112.0
#         2             8.0  127.375000   29.016929   80.0  109.25  128.0
#         3+            6.0  258.333333   78.614672  148.0  202.50  273.5
# Yes     0           168.0  145.416667   74.617220   25.0  107.75  129.5
#         1            76.0  170.236842  103.196882   26.0  110.75  148.5
#         2            90.0  152.255556   73.625313   17.0  108.25  133.0
#         3+           43.0  181.488372  138.986188   40.0  100.00  128.0
#
#                        75%    max
# Married Dependents
# No      0           140.00  650.0
#         1           151.50  196.0
#         2           144.00  166.0
#         3+          313.00  350.0
# Yes     0           168.50  570.0
#         1           185.25  600.0
# ...

# %%
df.groupby(['Married',df['Dependents'] == '3+'])['LoanAmount'].max()
# Out:
# Married  Dependents
# No       False         650.0
#          True          350.0
# Yes      False         600.0
#          True          700.0
# Name: LoanAmount, dtype: float64

# %%
sns.catplot(x='Married', y='LoanAmount', hue='Dependents',  data=df, row='Gender',kind='strip')

# %%
# applicantincome and and loan amount correlation
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df[['ApplicantIncome', 'LoanAmount']].corr()
# Out:
#                  ApplicantIncome  LoanAmount
# ApplicantIncome         1.000000    0.570909
# LoanAmount              0.570909    1.000000

# %%
sns.heatmap(data=df[['ApplicantIncome', 'LoanAmount']])
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x='ApplicantIncome',y='LoanAmount', data=df, estimator=df.corr)

# %%
# df.Property_Area.unique()
df.groupby(['Property_Area', 'Gender', 'Married', 'Self_Employed']).mean()
# df.pivot_table(values= 'LoanAmount', index='Loan_ID', columns='Property_Area')
# Out:
#                                             ApplicantIncome  \
# Property_Area Gender Married Self_Employed
# Rural         Female No      No                 3983.176471
#                              Yes                7441.000000
#                      Yes     No                 4422.000000
#                              Yes                6321.000000
#               Male   No      No                 5422.432432
#                              Yes                5124.250000
#                      Yes     No                 5734.289157
#                              Yes                7202.611111
# Semiurban     Female No      No                 4003.750000
#                              Yes                8592.428571
#                      Yes     No                 3635.294118
#                              Yes               19484.000000
#               Male   No      No                 5212.216216
#                              Yes                5554.000000
# ...

# %%
sns.catplot(x='Property_Area', y='LoanAmount', hue='Married', row='Gender', col='Self_Employed', kind='swarm', data=df, dodge=True,  height=10, aspect=1.3)

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...
